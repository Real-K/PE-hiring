# %% [markdown]
# # Revised exhibits — 0831 review memo
#
# Everything is regenerated from the aggregate artifacts in `../artifacts/`; no licensed microdata. Outputs are stored, so the notebook renders on GitHub.
# See `REVISION_MAP.md` for the memo-section → exhibit mapping and the PI decision flags.

# %% [markdown]
# ## Rebuild all revised tables

# %%
import runpy; runpy.run_path("build_tables.py", run_name="__main__")
import csv
n=len(list(csv.DictReader(open("REVISION_TRACE.csv",encoding="utf-8"))))
print("traced cells:",n); assert n==148
# Out:
# main cells traced 104 · appendix 44 · total 148 → main_exhibits.md, appendix_exhibits.md, REVISION_TRACE.csv
# traced cells: 148

# %% [markdown]
# ## Main-paper tables (1–5)

# %%
_md=open("main_exhibits.md",encoding="utf-8").read(); print("Tables 1–5 rendered")
# Out:
# # Main-paper exhibits, rebuilt to the 0831 review memo (5 tables + 2 figures)
#
# ### Table 1. Sample construction and characteristics of the matched population
#
# **Panel A. Sample construction**
#
# |  | Events |
# |---|---|
# | Private equity investment events identified | 752 |
# | &nbsp;&nbsp;unable to link to NPS records | −168 |
# | &nbsp;&nbsp;insufficient pre-investment history | −120 |
# | &nbsp;&nbsp;fewer than five insured employees at transaction | −75 |
# | &nbsp;&nbsp;no eligible baseline control cell | −10 |
# | **Baseline matched universe** | **379** |
# | Average-effect sample (≥6 observed months per window, target and a control) | 367 |
# | Conventional heterogeneity matching, without state balance | 301 |
# | **Primary state-balanced gradient sample** | **286** |
# | &nbsp;&nbsp;&nbsp;&nbsp;state window (months −24 to −13) not fully observed | −53 |
# | &nbsp;&nbsp;&nbsp;&nbsp;employment below five within the state window | −1 |
# ...

# %% [markdown]
# ## Changed appendix tables (E1 revised · E2–E3 inputs · B5 new)

# %%
_md=open("appendix_exhibits.md",encoding="utf-8").read(); print("appendix exhibits rendered")
# Out:
# # Appendix exhibits changed by the 0831 review memo
#
# ### Table E1 (revised). Sponsor experience at the transaction date and the hiring response
#
# | Prior sponsor deal count (before the focal transaction) | Mean response | 95% CI | Events |
# |---|---|---|---|
# | First observed deal (0 prior) | +0.1240 | [0.0219, 0.2276] | 158 |
# | 1–3 prior deals | +0.2749 | [0.1369, 0.4128] | 96 |
# | 4 or more prior deals | +0.1122 | [−0.0643, 0.3025] | 45 |
# | ≥4 − first-deal contrast | −0.0118 | [−0.2193, 0.2195] | — |
# | Repeat (≥1) − first-deal contrast | +0.0990 | [−0.0565, 0.2498] | — |
#
# *Notes.* Experience is the number of observed private equity deals by the same sponsor strictly before the focal transaction month, counted within the 379-event treated universe (no look-ahead). Share of first-observed deals: 0.53; correlation with the full-sample deal count: 0.74. Terciles are degenerate at zero, so fixed groups 0 / 1–3 / ≥4 are used.
#
# ...

# %% [markdown]
# ## Figure 1 — state–response relationship + actual placebo draws

# %%
import runpy; runpy.run_path("build_figure1.py", run_name="__main__")
_figs=[open("figure1_state_gradient.png","rb").read()]
# Out:
# saved figure1_state_gradient.png/.pdf

# %% [markdown]
# ## Figure 2 — quarterly dynamics (former Figure 1(a), markers removed)

# %%
import runpy; runpy.run_path("build_figure2.py", run_name="__main__")
_figs=[open("figure2_quarterly.png","rb").read()]
# Out:
# saved figure2_quarterly.png/.pdf
