# %% [markdown]
# # Main text — Tables 1–6
#
# Every number is read from an aggregate result artifact in `../artifacts/` — the files the submitted manuscript's tables were generated from.
# No licensed microdata is used or required (see `../DATA_ACCESS.md`). Outputs are stored, so the notebook renders on GitHub without running.
# The last cell compares every regenerated cell with the cell text extracted from the submitted .docx and raises on any difference.

# %% [markdown]
# ## Setup

# %%
import os, sys, json
sys.path.insert(0, "../code"); import render          # spec-driven renderer (../code/render.py)
spec = json.load(open("../spec/main_tables.json", encoding="utf-8"))
print(f"tables in spec: {len(spec)} · artifacts: {len([f for f in os.listdir('../artifacts') if f.endswith('.json')])}")
# Out:
# tables in spec: 11 · artifacts: 70

# %% [markdown]
# ## Table 1. Sample construction, characteristics, and covariate balance — Panel A. Sample

# %%
md, rows = render.render_table(spec[0]); _md = md
print("Table 1. Sample construction, characteristics, and covariate balance —")
# Out:
# **Table 1. Sample construction, characteristics, and covariate balance** — Panel A. Sample
#
# | Private equity investments identified | 752 |
# |---|---|
# | no pension record | 168 |
# | incomplete pre-deal window | 120 |
# | fewer than five insured employees | 75 |
# | no eligible control cell | 10 |
# | Baseline matched design | 379 |
# | with  6 observed months in each window, target and a control (Table 2) | 367 |
# | memo: conventional heterogeneity design, no state in the cell | 301 |
# | with state-balanced controls (primary gradient) | 286 |
# | with all deal characteristics observed | 180 |
# | with audited financial statements | 147 |
# | with complete pre-deal covariates (Panel D) | 366 |
# | Matched control firms (5 per target, never treated) | 1,895 |
# | Firm-months in the hazard sample | 48,853 |
# | Two-digit industries represented | 44 |
# Table 1. Sample construction, characteristics, and covariate balance —

# %% [markdown]
# ## Table 1. Sample construction, characteristics, and covariate balance — Panel B. Targets at the deal

# %%
md, rows = render.render_table(spec[1]); _md = md
print("Table 1. Sample construction, characteristics, and covariate balance —")
# Out:
# **Table 1. Sample construction, characteristics, and covariate balance** — Panel B. Targets at the deal
#
# | Median employees | 79 |
# |---|---|
# | Mean employees | 218.2 |
# | Median deal year | 2021 |
# | Share of firm-months with no hiring, pre-deal | 0.269 |
# | Mean intensity within active months (hires / employees) | 0.055 |
# Table 1. Sample construction, characteristics, and covariate balance —

# %% [markdown]
# ## Table 1. Sample construction, characteristics, and covariate balance — Panel C. The pre-deal hiring state

# %%
md, rows = render.render_table(spec[2]); _md = md
print("Table 1. Sample construction, characteristics, and covariate balance —")
# Out:
# **Table 1. Sample construction, characteristics, and covariate balance** — Panel C. The pre-deal hiring state
#
# | Pre-deal hiring state: , months −24 to −13 | Pre-deal hiring state: , months −24 to −13 |
# |---|---|
# | Normalized difference, treated versus controls, previous design | −0.0362 |
# | Normalized difference, state-balanced design | −0.0078 |
# | Correlation of treated and control state, previous / balanced | 0.3659 / 0.7614 |
# | Auxiliary: share of no-hire months, tercile cut points | 0.083 / 0.333 |
# Table 1. Sample construction, characteristics, and covariate balance —

# %% [markdown]
# ## Table 1. Sample construction, characteristics, and covariate balance — Panel D. Covariate balance

# %%
md, rows = render.render_table(spec[3]); _md = md
print("Table 1. Sample construction, characteristics, and covariate balance —")
# Out:
# **Table 1. Sample construction, characteristics, and covariate balance** — Panel D. Covariate balance
#
# |  | Treated | Matched controls | ND | Unmatched pool | ND |
# |---|---|---|---|---|---|
# | Employees | 218.2 | 228.1 | −0.012 | 97.2 | +0.175 |
# | Log employees | 4.420 | 4.421 | −0.000 | 3.531 | +0.753 |
# | Pre-deal employment growth | 0.142 | 0.130 | +0.032 | 0.063 | +0.116 |
# | Firm age (years) | 15.5 | 16.4 | −0.091 | 17.7 | −0.229 |
# | Hiring rate, prior 12 months | 0.444 | 0.428 | +0.051 | 0.379 | +0.184 |
# | Separation rate, prior 12 months | 0.358 | 0.367 | −0.037 | 0.371 | −0.041 |
# | Share of no-hire months, 12 to 1 | 0.269 | 0.288 | −0.076 | 0.500 | −0.786 |
# | Share of no-hire months, 24 to 13 | 0.282 | 0.306 | −0.095 | 0.496 | −0.724 |
# Table 1. Sample construction, characteristics, and covariate balance —

# %% [markdown]
# ## Table 2. Average post-investment employment and hiring responses

# %%
md, rows = render.render_table(spec[4]); _md = md
print("Table 2. Average post-investment employment and hiring responses")
# Out:
# **Table 2. Average post-investment employment and hiring responses**
#
# |  | Estimate | 95% Interval | Events |
# |---|---|---|---|
# | Employment, 12 months after ( log) | 0.0878 | [0.0462, 0.1300] | 367 |
# | 12-month hiring rate | 0.0485 | [0.0163, 0.0814] | 367 |
# | Separation rate | 0.0007 | [−0.0353, 0.0398] | 367 |
# Table 2. Average post-investment employment and hiring responses

# %% [markdown]
# ## Table 3. Hiring responses by pre-deal hiring intensity — Panel A. Primary gradient

# %%
md, rows = render.render_table(spec[5]); _md = md
print("Table 3. Hiring responses by pre-deal hiring intensity — Panel A. Prim")
# Out:
# **Table 3. Hiring responses by pre-deal hiring intensity** — Panel A. Primary gradient
#
# | Estimate | Value |
# |---|---|
# | Gradient in log hiring rate | 0.7101 [0.3187, 1.1254] |
# | Placebo null, mean (SD) | 0.101 (0.1538) |
# | Excess over placebo mean | 0.6091 |
# | Upper-tail placebo | 0.0005 |
# | Effect of an interquartile move | 0.2005 [0.0900, 0.3177] |
# Table 3. Hiring responses by pre-deal hiring intensity — Panel A. Prim

# %% [markdown]
# ## Table 3. Hiring responses by pre-deal hiring intensity — Panel B. Effect of matching on the hiring state

# %%
md, rows = render.render_table(spec[6]); _md = md
print("Table 3. Hiring responses by pre-deal hiring intensity — Panel B. Effe")
# Out:
# **Table 3. Hiring responses by pre-deal hiring intensity** — Panel B. Effect of matching on the hiring state
#
# | Specification | Gradient |
# |---|---|
# | Previous matching, common sample | 0.4698 |
# | State-balanced matching, common sample | 0.7101 |
# | Treated-firm gradient, previous / state-balanced | 0.8425 / 0.8425 |
# | Control-group gradient, previous / state-balanced | 0.2950 / 0.0056 |
# Table 3. Hiring responses by pre-deal hiring intensity — Panel B. Effe

# %% [markdown]
# ## Table 3. Hiring responses by pre-deal hiring intensity — Panel C. Hiring counts and employment

# %%
md, rows = render.render_table(spec[7]); _md = md
print("Table 3. Hiring responses by pre-deal hiring intensity — Panel C. Hiri")
# Out:
# **Table 3. Hiring responses by pre-deal hiring intensity** — Panel C. Hiring counts and employment
#
# | Outcome/specification | Gradient | Placebo benchmark |
# |---|---|---|
# | Log count of hires | 0.6315 | 0.1795 |
# | Log hires, controlling for change in log employment | 0.6957 | 0.0363 |
# | Log employment | −0.0580 | 0.0796 |
# Table 3. Hiring responses by pre-deal hiring intensity — Panel C. Hiri

# %% [markdown]
# ## Table 4. Worker-flow responses by pre-deal hiring state

# %%
md, rows = render.render_table(spec[8]); _md = md
print("Table 4. Worker-flow responses by pre-deal hiring state")
# Out:
# **Table 4. Worker-flow responses by pre-deal hiring state**
#
# |  | Estimate | 95% CI | Events |
# |---|---|---|---|
# | Panel A. State gradient by outcome | Panel A. State gradient by outcome | Panel A. State gradient by outcome | Panel A. State gradient by outcome |
# | Log hiring rate | 0.7101 | — | 286 |
# | Log churn, (hires + separations) / employment | 0.3816 | z = 3.08 | 288 |
# | Log separation rate | 0.1788 | z = 1.17, p = 0.2349 | 281 |
# | Log employment | −0.0580 | z = −2.6, p = 0.007 | 289 |
# | Panel B. Within-event contrasts (same events) | Panel B. Within-event contrasts (same events) | Panel B. Within-event contrasts (same events) | Panel B. Within-event contrasts (same events) |
# | Hiring  employment | 0.7536 | null 0.0232, z = 4.56 | 286 |
# | Churn  employment | 0.4539 | z = 4.19 | — |
# Table 4. Worker-flow responses by pre-deal hiring state

# %% [markdown]
# ## Table 5. Pre-deal dynamics of the hiring-state gradient

# %%
md, rows = render.render_table(spec[9]); _md = md
print("Table 5. Pre-deal dynamics of the hiring-state gradient")
# Out:
# **Table 5. Pre-deal dynamics of the hiring-state gradient**
#
# |  | Value | 95% Interval | Events |
# |---|---|---|---|
# | Pre-deal excess gradient, non-overlapping state window | −0.0777 | [−0.4394, 0.0854] | 250 |
# | Pre-deal gradient, usual state window | 0.1068 | [−0.1955, 0.4351] | 283 |
# | Post-deal gradient, same events | 0.7250 | [0.3259, 1.1081] | 283 |
# | Relative-magnitude breakdown, gradient | 3.126 | — | — |
# Table 5. Pre-deal dynamics of the hiring-state gradient

# %% [markdown]
# ## Table 6. Monthly hiring patterns relative to a volume benchmark

# %%
md, rows = render.render_table(spec[10]); _md = md
print("Table 6. Monthly hiring patterns relative to a volume benchmark")
# Out:
# **Table 6. Monthly hiring patterns relative to a volume benchmark**
#
# |  | Estimate | 95% CI | Events |
# |---|---|---|---|
# | Share of no-hire months: actual change | −0.0466 | [−0.0675, −0.0270 | 346 |
# | Change implied by the volume increase alone | −0.0518 | [−0.0699, −0.0326] | - |
# | Excess, over and above the benchmark | 0.0052 | [−0.0082, 0.0189] | 346 |
# Table 6. Monthly hiring patterns relative to a volume benchmark

# %% [markdown]
# ## Check — every regenerated cell equals the submitted manuscript's cell

# %%
n, bad = render.check(spec)
lit = [(T["caption"], c["text"]) for T in spec for row in T["rows"] for c in row for t in c.get("tokens", []) if t["src"]["kind"] == "literal"]
print(f"cells checked {n} · mismatches {len(bad)} · untraceable literals {len(lit)}")
for l in lit: print("  LITERAL (flagged, see PLACEHOLDERS_RESOLVED.md):", l)
assert not bad
# Out:
# cells checked 122 · mismatches 0 · untraceable literals 0
